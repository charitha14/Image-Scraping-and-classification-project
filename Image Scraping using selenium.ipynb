# %%
import selenium
from selenium import webdriver
import pandas as pd
import numpy as np
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.edge.service import Service
from selenium.webdriver.common.by import By

# %%
s=Service("msedgedriver.exe")

# %%
driver = webdriver.Chrome(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\chromedriver_win32 (3)\chromedriver.exe")
# Out:
# C:\Users\HUCONS~1\AppData\Local\Temp/ipykernel_12736/208609420.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\HUCON SOLUTIONS PVT\Downloads\chromedriver_win32 (3)\chromedriver.exe")

# %% [markdown]
# # Scraping for images of Saree:

# %%
url='https://www.amazon.in/s?k=saree&ref=nb_sb_noss_2'
driver.get(url)

# %%
sarees=[]

for j in range(0,4):

    saree_tag=driver.find_elements(By.XPATH,"//div[@class='a-section aok-relative s-image-tall-aspect']")
    for i in saree_tag:
        dataset1=i.find_element(By.TAG_NAME,"img")
        saree=sarees.append(dataset1.get_attribute('src'))
    button=driver.find_element(By.XPATH,"//*[contains(text(), 'Next')]")
    driver.execute_script("arguments[0].click();", button)
    time.sleep(5)

# %%
len(sarees)
# Out:
# 256

# %%
for j in range(0,4):

    saree_tag=driver.find_elements(By.XPATH,"//div[@class='a-section aok-relative s-image-tall-aspect']")
    for i in saree_tag:
        dataset1=i.find_element(By.TAG_NAME,"img")
        saree=sarees.append(dataset1.get_attribute('src'))
    button=driver.find_element(By.XPATH,"//*[contains(text(), 'Next')]")
    driver.execute_script("arguments[0].click();", button)
    time.sleep(5)

# %%
len(sarees)
# Out:
# 436

# %%
sarees
# Out:
# ['https://m.media-amazon.com/images/I/71KLHiGZx6S._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71PD4K1WqqL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/6160TlEohVS._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71satUgK-yL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71XAzGJXvkL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91rgA6YHVcL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91EY+8yxCbL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/711vlC6N6bL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/8146BLEzqPL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91njmlSKiCL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61ycr0TYRLL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/715gq48jKsL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91hrK4R8YdL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91vgYb-7tGL._AC_UL320_.jpg',
# ...

# %% [markdown]
# # Scraping images for Trousers:

# %%
url='https://www.amazon.in/s?k=trousers+for+men&crid=K3FCCGFZZAQ7&sprefix=trousers%2Caps%2C459&ref=nb_sb_ss_ts-doa-p_1_8'
driver.get(url)

# %%
trousers=[]

for j in range(0,4):

    trouser_tag=driver.find_elements(By.XPATH,"//div[@class='a-section aok-relative s-image-tall-aspect']")
    for i in trouser_tag:
        dataset1=i.find_element(By.TAG_NAME,"img")
        trouser=trousers.append(dataset1.get_attribute('src'))
    button=driver.find_element(By.XPATH,"//*[contains(text(), 'Next')]")
    driver.execute_script("arguments[0].click();", button)
    time.sleep(5)

# %%
len(trousers)
# Out:
# 240

# %%
for j in range(0,4):

    trouser_tag=driver.find_elements(By.XPATH,"//div[@class='a-section aok-relative s-image-tall-aspect']")
    for i in trouser_tag:
        dataset1=i.find_element(By.TAG_NAME,"img")
        trouser=trousers.append(dataset1.get_attribute('src'))
    button=driver.find_element(By.XPATH,"//*[contains(text(), 'Next')]")
    driver.execute_script("arguments[0].click();", button)
    time.sleep(5)

# %%
len(trousers)
# Out:
# 420

# %%
trousers
# Out:
# ['https://m.media-amazon.com/images/I/81Lg1x1O29L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61YHtYYabpL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71HrKHZ6RUL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61eycNXPDoL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/718kU7VISWL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71mdP1wsxXL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61YHtYYabpL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81Lg1x1O29L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81t3XS8UciL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51rnYLGXVxL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/6179ubSzTcL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61A04Ru4T+L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61HwCsXHbzL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51d74502ZVL._AC_UL320_.jpg',
# ...

# %% [markdown]
# # Scraping Images for Jeans:

# %%
url='https://www.amazon.in/s?k=jeans+mens&crid=3OMKVC4D45NVI&sprefix=jeans+m%2Caps%2C411&ref=nb_sb_ss_ts-doa-p_2_7'
driver.get(url)

# %%
jeans=[]

for j in range(0,4):

    jeans_tag=driver.find_elements(By.XPATH,"//div[@class='a-section aok-relative s-image-tall-aspect']")
    for i in jeans_tag:
        dataset1=i.find_element(By.TAG_NAME,"img")
        jean=jeans.append(dataset1.get_attribute('src'))
    button=driver.find_element(By.XPATH,"//*[contains(text(), 'Next')]")
    driver.execute_script("arguments[0].click();", button)
    time.sleep(5)

# %%
len(jeans)
# Out:
# 252

# %%
for j in range(0,4):

    jeans_tag=driver.find_elements(By.XPATH,"//div[@class='a-section aok-relative s-image-tall-aspect']")
    for i in jeans_tag:
        dataset1=i.find_element(By.TAG_NAME,"img")
        jean=jeans.append(dataset1.get_attribute('src'))
    button=driver.find_element(By.XPATH,"//*[contains(text(), 'Next')]")
    driver.execute_script("arguments[0].click();", button)
    time.sleep(5)

# %%
len(jeans)
# Out:
# 432

# %%
jeans
# Out:
# ['https://m.media-amazon.com/images/I/71ItZz1lOMS._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/21gi-urcpBL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51bZyXZG8KL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51Uj3vWLUsL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81vFqVxqiWL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71OvAKyFpCL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61D3NhllkbL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81hGDOVlVeL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51jhrmjynGL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51sKHDOcm2L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/616xchp1ECL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81dZ97Jc2GL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81y1h+SZWBL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81D+KVOvp2L._AC_UL320_.jpg',
# ...

# %%
sarees=sarees[:420]
trousers=trousers[:420]
jeans=jeans[:420]

# %% [markdown]
# we have 420 images of each type of clothes

# %%
import os
import shutil
import requests

def directory(dir):
    current_path=os.getcwd()
    new=os.path.join(current_path,dir)
    if not os.path.exists(new):
        os.makedirs(new)
        
directory('Sarees_Images')
directory('Trousers_Images')
directory('Jeans_Images')

# %%
for index, link in enumerate(sarees):
    print('Downloading {0} of 420 saree images'.format(index+1))
    response=requests.get(link)
    with open('Sarees_Images/img{0}.jpeg'.format(index+1),"wb") as file:
        file.write(response.content)

# %%
for index, link in enumerate(trousers):
    print('Downloading {0} of 420 trouser images'.format(index+1))
    response=requests.get(link)
    with open('Trousers_Images/img{0}.jpeg'.format(index+1),"wb") as file:
        file.write(response.content)

# %%
for index, link in enumerate(jeans):
    print('Downloading {0} of 420 jeans images'.format(index+1))
    response=requests.get(link)
    with open('Jeans_Images/img{0}.jpeg'.format(index+1),"wb") as file:
        file.write(response.content)

# %% [markdown]
# All images have been downloaded and saved
